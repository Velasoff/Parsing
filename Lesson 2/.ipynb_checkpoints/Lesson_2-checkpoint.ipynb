# %%
from pprint import pprint
from bs4 import BeautifulSoup as bs
import requests

# %%
main_link = 'https://hh.ru/'
header = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36'}

# %%
print('Введите название вакансии: ')
name = input()
name = name.replace(' ', '+')
# Out:
# Введите название вакансии:
# Python

# %%
print('Сколько страниц просматривать? ')
page = int(input())
# Out:
# Сколько страниц просматривать?
# 2

# %%
vacancies = []
for i in range(page):    
    response = requests.get(main_link + f'search/vacancy?clusters=true&area=1&enable_snippets=true&salary=&st=searchVacancy&text={name}&page={i}', headers=header).text
    html = bs(response, 'lxml')
    vacancies_block = html.find('div', {'class': 'vacancy-serp'})
    vacancies_list = vacancies_block.findChildren(recursive=False)
    for vacancy in vacancies_list:
        vacancy_data = {}
        main_info = vacancy.find('div', {'class': 'vacancy-serp-item__row vacancy-serp-item__row_header'})
        if main_info is not None:
            salary = main_info.find('div', {'class': 'vacancy-serp-item__compensation'})
            if salary is None:
                min_salary = 'None'
                max_salary = 'None'
            else:
                salary = salary.getText()[0:-5].replace("\xa0", '').replace('-', ' ')
                if salary.find('от') == 0:
                    min_salary = int(salary[3:])
                    max_salary = 'None'
                elif salary.find('до') == 0:
                    min_salary = 'None'
                    max_salary = int(salary[3:])
                else:
                    min_salary, max_salary = [int(i) for i in salary.split(' ')]
            main_info = main_info.findChild()
            vacancy_name = main_info.getText()
            vacancy_text = main_info.getText
            vacancy_link = str(vacancy_text)[str(vacancy_text).find('http'):str(vacancy_text).find('target=')-2]
        else:
            continue
        vacancy_data['name'] = vacancy_name
        vacancy_data['min_salary'] = min_salary
        vacancy_data['max_salary'] = max_salary
        vacancy_data['link'] = vacancy_link
        vacancy_data['site'] = main_link
        vacancies.append(vacancy_data)

# %%
main_link='https://www.superjob.ru/'
for i in range(page):       
    response = requests.get(main_link + f'vacancy/search/?keywords={name}&geo[c][0]=1&page={i}', headers=header).text
    html = bs(response, 'lxml')
    vacancies_block = html.findAll('div', {'class': '_3zucV _2GPIV f-test-vacancy-item i6-sc _3VcZr'})
    for vacancy in vacancies_block:
        vacancy_data = {}
        vacancy_name = vacancy.find('div', {'class': '_3mfro CuJz5 PlM3e _2JVkc _3LJqf'}).getText()
        salary = vacancy.find('span', {'class': '_3mfro _2Wp8I f-test-text-company-item-salary PlM3e _2JVkc _2VHxz'}).getText()
        if salary == 'По договорённости':
            min_salary = 'None'
            max_salary = 'None'
        else:
            salary = salary[0:-1].replace("\xa0", '').replace('—', ' ')
            if salary.find('от') == 0:
                min_salary = int(salary[2:])
                max_salary = 'None'
            elif salary.find('до') == 0:
                min_salary = 'None'
                max_salary = int(salary[2:])
            else:
                min_salary, max_salary = [int(i) for i in salary.split(' ')]
        vacancy_text = vacancy.getText
        vacancy_link = main_link + str(vacancy_text)[str(vacancy_text).find('href="/vakansii')+7:str(vacancy_text).find('target=', str(vacancy_text).find('href="/vakansii')) - 2]

        vacancy_data['name'] = vacancy_name
        vacancy_data['min_salary'] = min_salary
        vacancy_data['max_salary'] = max_salary
        vacancy_data['link'] = vacancy_link
        vacancy_data['site'] = main_link
        vacancies.append(vacancy_data)
pprint(vacancies)
# Out:
# [{'link': 'https://nn.hh.ru/vacancy/35660654?query=Python',
#   'max_salary': 110000,
#   'min_salary': 90000,
#   'name': 'ML разработчик, python',
#   'site': 'https://hh.ru/'},
#  {'link': 'https://nn.hh.ru/vacancy/34200113?query=Python',
#   'max_salary': 'None',
#   'min_salary': 200000,
#   'name': 'Ведущий разработчик Python / Software development / Team lead',
#   'site': 'https://hh.ru/'},
#  {'link': 'https://nn.hh.ru/vacancy/35011897?query=Python',
#   'max_salary': 'None',
#   'min_salary': 200000,
#   'name': 'Data Scientist',
#   'site': 'https://hh.ru/'},
#  {'link': 'https://nn.hh.ru/vacancy/35571320?query=Python',
#   'max_salary': 'None',
#   'min_salary': 'None',
#   'name': 'Тестировщик / QA',
#   'site': 'https://hh.ru/'},
#  {'link': 'https://nn.hh.ru/vacancy/35661239?query=Python',
#   'max_salary': 'None',
#   'min_salary': 'None',
#   'name': 'Senior Data Analyst',
#   'site': 'https://hh.ru/'},
#  {'link': 'https://nn.hh.ru/vacancy/35661206?query=Python',
#   'max_salary': 'None',
#   'min_salary': 'None',
#   'name': 'Senior Data Engineer',
#   'site': 'https://hh.ru/'},
#  {'link': 'https://nn.hh.ru/vacancy/35121709?query=Python',
#   'max_salary': 'None',
#   'min_salary': 'None',
#   'name': 'Аналитик (команда Поиска)',
#   'site': 'https://hh.ru/'},
#  {'link': 'https://nn.hh.ru/vacancy/35613327?query=Python',
#   'max_salary': 'None',
#   'min_salary': 'None',
#   'name': 'Специалист по анализу данных',
#   'site': 'https://hh.ru/'},
#  {'link': 'https://nn.hh.ru/vacancy/32481016?query=Python',
#   'max_salary': 'None',
#   'min_salary': 'None',
#   'name': 'IOS Developer',
#   'site': 'https://hh.ru/'},
#  {'link': 'https://nn.hh.ru/vacancy/35105576?query=Python',
#   'max_salary': 150000,
#   'min_salary': 150000,
#   'name': 'Системный администратор Linux / DevOps/Митино',
#   'site': 'https://hh.ru/'},
#  {'link': 'https://nn.hh.ru/vacancy/34746892?query=Python',
#   'max_salary': 'None',
#   'min_salary': 230000,
#   'name': 'Senior Frontend Developer (JavaScript, React)',
#   'site': 'https://hh.ru/'},
#  {'link': 'https://nn.hh.ru/vacancy/35503487?query=Python',
#   'max_salary': 200000,
#   'min_salary': 140000,
#   'name': 'Python-разработчик',
#   'site': 'https://hh.ru/'},
#  {'link': 'https://nn.hh.ru/vacancy/34800575?query=Python',
#   'max_salary': 150000,
#   'min_salary': 100000,
#   'name': 'Программист Python/C++',
#   'site': 'https://hh.ru/'},
#  {'link': 'https://nn.hh.ru/vacancy/35506627?query=Python',
#   'max_salary': 160000,
#   'min_salary': 140000,
#   'name': 'Python разработчик',
#   'site': 'https://hh.ru/'},
#  {'link': 'https://nn.hh.ru/vacancy/35546587?query=Python',
#   'max_salary': 500000,
#   'min_salary': 130000,
#   'name': 'Data scientist',
#   'site': 'https://hh.ru/'},
#  {'link': 'https://nn.hh.ru/vacancy/35447884?query=Python',
#   'max_salary': 230000,
#   'min_salary': 'None',
#   'name': 'Python-разработчик (Middle Python Developer)',
#   'site': 'https://hh.ru/'},
#  {'link': 'https://nn.hh.ru/vacancy/35447201?query=Python',
#   'max_salary': 250000,
#   'min_salary': 200000,
#   'name': 'Старший разработчик Python',
#   'site': 'https://hh.ru/'},
#  {'link': 'https://nn.hh.ru/vacancy/30005963?query=Python',
#   'max_salary': 'None',
#   'min_salary': 400,
#   'name': 'Python developer',
#   'site': 'https://hh.ru/'},
#  {'link': 'https://nn.hh.ru/vacancy/34831620?query=Python',
#   'max_salary': 300000,
#   'min_salary': 200000,
#   'name': 'Python Web Developer',
#   'site': 'https://hh.ru/'},
#  {'link': 'https://nn.hh.ru/vacancy/33416348?query=Python',
#   'max_salary': 220000,
#   'min_salary': 'None',
#   'name': 'Python разработчик / Python software developer',
#   'site': 'https://hh.ru/'},
#  {'link': 'https://nn.hh.ru/vacancy/35431519?query=Python',
#   'max_salary': 'None',
#   'min_salary': 'None',
#   'name': 'Стажёр (Анализ данных, data science)',
#   'site': 'https://hh.ru/'},
#  {'link': 'https://nn.hh.ru/vacancy/35296762?query=Python',
#   'max_salary': 'None',
#   'min_salary': 150000,
#   'name': 'Python Data Scientist',
#   'site': 'https://hh.ru/'},
#  {'link': 'https://nn.hh.ru/vacancy/35447928?query=Python',
#   'max_salary': 400000,
#   'min_salary': 'None',
#   'name': 'Ведущий Python-разработчик (Senior / TechLead Python Developer в '
#           'Rubbles)',
#   'site': 'https://hh.ru/'},
#  {'link': 'https://nn.hh.ru/vacancy/35610836?query=Python',
#   'max_salary': 160000,
#   'min_salary': 100000,
#   'name': 'Python backend developer',
#   'site': 'https://hh.ru/'},
#  {'link': 'https://nn.hh.ru/vacancy/35336146?query=Python',
#   'max_salary': 180000,
#   'min_salary': 160000,
#   'name': 'Python developer',
#   'site': 'https://hh.ru/'},
#  {'link': 'https://nn.hh.ru/vacancy/35291489?query=Python',
#   'max_salary': 50000,
#   'min_salary': 40000,
#   'name': 'Junior Python разработчик',
#   'site': 'https://hh.ru/'},
#  {'link': 'https://nn.hh.ru/vacancy/35218725?query=Python',
#   'max_salary': 'None',
#   'min_salary': 'None',
#   'name': 'Junior Data scientist',
#   'site': 'https://hh.ru/'},
#  {'link': 'https://nn.hh.ru/vacancy/31844648?query=Python',
#   'max_salary': 250000,
#   'min_salary': 250000,
#   'name': 'Junior Quantitative Researcher',
#   'site': 'https://hh.ru/'},
#  {'link': 'https://nn.hh.ru/vacancy/35196412?query=Python',
#   'max_salary': 200000,
#   'min_salary': 150000,
#   'name': 'Python developer',
#   'site': 'https://hh.ru/'},
#  {'link': 'https://nn.hh.ru/vacancy/35392114?query=Python',
#   'max_salary': 580,
#   'min_salary': 4200,
#   'name': 'Web Developer with Angular/Python (Berlin)',
#   'site': 'https://hh.ru/'},
#  {'link': 'https://nn.hh.ru/vacancy/35185238?query=Python',
#   'max_salary': 'None',
#   'min_salary': 100000,
#   'name': 'Разработчик Python/Django в Сочи',
#   'site': 'https://hh.ru/'},
#  {'link': 'https://nn.hh.ru/vacancy/34498750?query=Python',
#   'max_salary': 'None',
#   'min_salary': 'None',
#   'name': 'Web разработчик (Python)',
#   'site': 'https://hh.ru/'},
#  {'link': 'https://nn.hh.ru/vacancy/35436560?query=Python',
#   'max_salary': 'None',
#   'min_salary': 'None',
#   'name': 'Разработчик Python',
#   'site': 'https://hh.ru/'},
#  {'link': 'https://nn.hh.ru/vacancy/35485835?query=Python',
#   'max_salary': 'None',
#   'min_salary': 'None',
#   'name': 'Разработчик Python',
#   'site': 'https://hh.ru/'},
#  {'link': 'https://nn.hh.ru/vacancy/30424698?query=Python',
#   'max_salary': 'None',
#   'min_salary': 220000,
#   'name': 'Senior Python разработчик',
#   'site': 'https://hh.ru/'},
#  {'link': 'https://nn.hh.ru/vacancy/35568546?query=Python',
#   'max_salary': 'None',
#   'min_salary': 'None',
#   'name': 'Программист Python',
#   'site': 'https://hh.ru/'},
#  {'link': 'https://nn.hh.ru/vacancy/35296509?query=Python',
#   'max_salary': 'None',
#   'min_salary': 150000,
#   'name': 'Разработчик Python Backend',
#   'site': 'https://hh.ru/'},
#  {'link': 'https://nn.hh.ru/vacancy/35697557?query=Python',
#   'max_salary': 250000,
#   'min_salary': 180000,
#   'name': 'Ведущий программист Python+Django',
#   'site': 'https://hh.ru/'},
#  {'link': 'https://nn.hh.ru/vacancy/35631853?query=Python',
#   'max_salary': 'None',
#   'min_salary': 'None',
#   'name': 'Junior Python Developer',
#   'site': 'https://hh.ru/'},
#  {'link': 'https://nn.hh.ru/vacancy/35286646?query=Python',
#   'max_salary': 160000,
#   'min_salary': 120000,
#   'name': 'Python middle developer',
#   'site': 'https://hh.ru/'},
#  {'link': 'https://www.superjob.ru/vakansii/programmist-razrabotchik-33340430.html',
#   'max_salary': 'None',
#   'min_salary': 'None',
#   'name': 'Программист-разработчик (Python 3, Docker, Go, Javascript)',
#   'site': 'https://www.superjob.ru/'},
#  {'link': 'https://www.superjob.ru/vakansii/team-leader-c-33445875.html',
#   'max_salary': 100000,
#   'min_salary': 'None',
#   'name': 'Team Leader C++, Python',
#   'site': 'https://www.superjob.ru/'},
#  {'link': 'https://www.superjob.ru/vakansii/middle-33477906.html',
#   'max_salary': 'None',
#   'min_salary': 'None',
#   'name': 'Middle / senior Python разработчик',
#   'site': 'https://www.superjob.ru/'},
#  {'link': 'https://www.superjob.ru/vakansii/programmist-python-33389416.html',
#   'max_salary': 'None',
#   'min_salary': 'None',
#   'name': 'Программист Python (Python\\Django\\HTML\\CSS\\JS)',
#   'site': 'https://www.superjob.ru/'},
#  {'link': 'https://www.superjob.ru/vakansii/veduschij-razrabotchik-python-33338587.html',
#   'max_salary': 300000,
#   'min_salary': 150000,
#   'name': 'Ведущий разработчик Python',
#   'site': 'https://www.superjob.ru/'},
#  {'link': 'https://www.superjob.ru/vakansii/senior-python-33441665.html',
#   'max_salary': 200000,
#   'min_salary': 'None',
#   'name': 'Senior Python (Team Lead) Developer',
#   'site': 'https://www.superjob.ru/'},
#  {'link': 'https://www.superjob.ru/vakansii/razrabotchik-python-33258416.html',
#   'max_salary': 'None',
#   'min_salary': 'None',
#   'name': 'Разработчик Python',
#   'site': 'https://www.superjob.ru/'},
#  {'link': 'https://www.superjob.ru/vakansii/programmist-python-32539725.html',
#   'max_salary': 'None',
#   'min_salary': 'None',
#   'name': 'Программист Python',
#   'site': 'https://www.superjob.ru/'},
#  {'link': 'https://www.superjob.ru/vakansii/web-razrabotchik-python-33437842.html',
#   'max_salary': 'None',
#   'min_salary': 100000,
#   'name': 'Web-разработчик Python',
#   'site': 'https://www.superjob.ru/'},
#  {'link': 'https://www.superjob.ru/vakansii/programmist-python-33437791.html',
#   'max_salary': 'None',
#   'min_salary': 150000,
#   'name': 'Программист Python',
#   'site': 'https://www.superjob.ru/'},
#  {'link': 'https://www.superjob.ru/vakansii/web-analitik-33473129.html',
#   'max_salary': 150000,
#   'min_salary': 120000,
#   'name': 'Web-аналитик',
#   'site': 'https://www.superjob.ru/'},
#  {'link': 'https://www.superjob.ru/vakansii/starshij-sistemnyj-administrator-33397656.html',
#   'max_salary': 'None',
#   'min_salary': 'None',
#   'name': 'Старший системный администратор',
#   'site': 'https://www.superjob.ru/'},
#  {'link': 'https://www.superjob.ru/vakansii/full-stack-razrabotchik-33397634.html',
#   'max_salary': 'None',
#   'min_salary': 'None',
#   'name': 'Full-Stack разработчик',
#   'site': 'https://www.superjob.ru/'},
#  {'link': 'https://www.superjob.ru/vakansii/junior-data-scientist-33452044.html',
#   'max_salary': 'None',
#   'min_salary': 'None',
#   'name': 'Junior Data Scientist',
#   'site': 'https://www.superjob.ru/'},
#  {'link': 'https://www.superjob.ru/vakansii/administrator-baz-dannyh-postgresql-32992512.html',
#   'max_salary': 150000,
#   'min_salary': 'None',
#   'name': 'Администратор баз данных PostgreSQL',
#   'site': 'https://www.superjob.ru/'},
#  {'link': 'https://www.superjob.ru/vakansii/analitik-dannyh-33317124.html',
#   'max_salary': 'None',
#   'min_salary': 'None',
#   'name': 'Аналитик данных',
#   'site': 'https://www.superjob.ru/'},
#  {'link': 'https://www.superjob.ru/vakansii/rukovoditel-gruppy-testirovaniya-po-33397052.html',
#   'max_salary': 'None',
#   'min_salary': 'None',
#   'name': 'Руководитель группы тестирования ПО',
#   'site': 'https://www.superjob.ru/'},
#  {'link': 'https://www.superjob.ru/vakansii/veduschij-inzhener-33434299.html',
#   'max_salary': 'None',
#   'min_salary': 'None',
#   'name': 'Ведущий инженер',
#   'site': 'https://www.superjob.ru/'},
#  {'link': 'https://www.superjob.ru/vakansii/specialist-sektora-operacionnoj-effektivnosti-resursov-31814280.html',
#   'max_salary': 'None',
#   'min_salary': 'None',
#   'name': 'Специалист сектора операционной эффективности ресурсов',
#   'site': 'https://www.superjob.ru/'},
#  {'link': 'https://www.superjob.ru/vakansii/glavnyj-inzhener-33439556.html',
#   'max_salary': 'None',
#   'min_salary': 'None',
#   'name': 'Главный инженер',
#   'site': 'https://www.superjob.ru/'},
#  {'link': 'https://www.superjob.ru/vakansii/programmist-razrabotchik-33340430.html',
#   'max_salary': 'None',
#   'min_salary': 'None',
#   'name': 'Программист-разработчик (Python 3, Docker, Go, Javascript)',
#   'site': 'https://www.superjob.ru/'},
#  {'link': 'https://www.superjob.ru/vakansii/team-leader-c-33445875.html',
#   'max_salary': 100000,
#   'min_salary': 'None',
#   'name': 'Team Leader C++, Python',
#   'site': 'https://www.superjob.ru/'},
#  {'link': 'https://www.superjob.ru/vakansii/middle-33477906.html',
#   'max_salary': 'None',
#   'min_salary': 'None',
#   'name': 'Middle / senior Python разработчик',
#   'site': 'https://www.superjob.ru/'},
#  {'link': 'https://www.superjob.ru/vakansii/programmist-python-33389416.html',
#   'max_salary': 'None',
#   'min_salary': 'None',
#   'name': 'Программист Python (Python\\Django\\HTML\\CSS\\JS)',
#   'site': 'https://www.superjob.ru/'},
#  {'link': 'https://www.superjob.ru/vakansii/veduschij-razrabotchik-python-33338587.html',
#   'max_salary': 300000,
#   'min_salary': 150000,
#   'name': 'Ведущий разработчик Python',
#   'site': 'https://www.superjob.ru/'},
#  {'link': 'https://www.superjob.ru/vakansii/senior-python-33441665.html',
#   'max_salary': 200000,
#   'min_salary': 'None',
#   'name': 'Senior Python (Team Lead) Developer',
#   'site': 'https://www.superjob.ru/'},
#  {'link': 'https://www.superjob.ru/vakansii/razrabotchik-python-33258416.html',
#   'max_salary': 'None',
#   'min_salary': 'None',
#   'name': 'Разработчик Python',
#   'site': 'https://www.superjob.ru/'},
#  {'link': 'https://www.superjob.ru/vakansii/programmist-python-32539725.html',
#   'max_salary': 'None',
#   'min_salary': 'None',
#   'name': 'Программист Python',
#   'site': 'https://www.superjob.ru/'},
#  {'link': 'https://www.superjob.ru/vakansii/web-razrabotchik-python-33437842.html',
#   'max_salary': 'None',
#   'min_salary': 100000,
#   'name': 'Web-разработчик Python',
#   'site': 'https://www.superjob.ru/'},
#  {'link': 'https://www.superjob.ru/vakansii/programmist-python-33437791.html',
#   'max_salary': 'None',
#   'min_salary': 150000,
#   'name': 'Программист Python',
#   'site': 'https://www.superjob.ru/'},
#  {'link': 'https://www.superjob.ru/vakansii/web-analitik-33473129.html',
#   'max_salary': 150000,
#   'min_salary': 120000,
#   'name': 'Web-аналитик',
#   'site': 'https://www.superjob.ru/'},
#  {'link': 'https://www.superjob.ru/vakansii/starshij-sistemnyj-administrator-33397656.html',
#   'max_salary': 'None',
#   'min_salary': 'None',
#   'name': 'Старший системный администратор',
#   'site': 'https://www.superjob.ru/'},
#  {'link': 'https://www.superjob.ru/vakansii/full-stack-razrabotchik-33397634.html',
#   'max_salary': 'None',
#   'min_salary': 'None',
#   'name': 'Full-Stack разработчик',
#   'site': 'https://www.superjob.ru/'},
#  {'link': 'https://www.superjob.ru/vakansii/junior-data-scientist-33452044.html',
#   'max_salary': 'None',
#   'min_salary': 'None',
#   'name': 'Junior Data Scientist',
#   'site': 'https://www.superjob.ru/'},
#  {'link': 'https://www.superjob.ru/vakansii/administrator-baz-dannyh-postgresql-32992512.html',
#   'max_salary': 150000,
#   'min_salary': 'None',
#   'name': 'Администратор баз данных PostgreSQL',
#   'site': 'https://www.superjob.ru/'},
#  {'link': 'https://www.superjob.ru/vakansii/analitik-dannyh-33317124.html',
#   'max_salary': 'None',
#   'min_salary': 'None',
#   'name': 'Аналитик данных',
#   'site': 'https://www.superjob.ru/'},
#  {'link': 'https://www.superjob.ru/vakansii/rukovoditel-gruppy-testirovaniya-po-33397052.html',
#   'max_salary': 'None',
#   'min_salary': 'None',
#   'name': 'Руководитель группы тестирования ПО',
#   'site': 'https://www.superjob.ru/'},
#  {'link': 'https://www.superjob.ru/vakansii/veduschij-inzhener-33434299.html',
#   'max_salary': 'None',
#   'min_salary': 'None',
#   'name': 'Ведущий инженер',
#   'site': 'https://www.superjob.ru/'},
#  {'link': 'https://www.superjob.ru/vakansii/specialist-sektora-operacionnoj-effektivnosti-resursov-31814280.html',
#   'max_salary': 'None',
#   'min_salary': 'None',
#   'name': 'Специалист сектора операционной эффективности ресурсов',
#   'site': 'https://www.superjob.ru/'},
#  {'link': 'https://www.superjob.ru/vakansii/glavnyj-inzhener-33439556.html',
#   'max_salary': 'None',
#   'min_salary': 'None',
#   'name': 'Главный инженер',
#   'site': 'https://www.superjob.ru/'}]
